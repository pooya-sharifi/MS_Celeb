# %%
import Augmentor
p = Augmentor.Pipeline("C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/anne_hathaway")
# Out:
# Initialised with 226 image(s) found.
# Output directory set to C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/anne_hathaway\output.

# %%
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.zoom(probability=0.5, min_factor=1.1, max_factor=1.5)
p.flip_top_bottom(probability=0.5)
p.random_distortion(probability=1, grid_width=4, grid_height=4, magnitude=8)

p.sample(80)
# Out:
# Executing Pipeline:   0%|          | 0/80 [00:02<?, ? Samples/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\Augmentor\Pipeline.py in _execute(self, augmentor_image, save_to_disk, multi_threaded)
#     250
# --> 251                         images[i].save(os.path.join(augmentor_image.output_directory, save_name))
#     252
#
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2349             else:
# -> 2350                 fp = builtins.open(filename, "w+b")
#    2351
#
# ...

# %%
p = Augmentor.Pipeline("C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/arnold_schwarzenegger")
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.zoom(probability=0.5, min_factor=1.1, max_factor=1.5)
p.flip_top_bottom(probability=0.5)
p.random_distortion(probability=1, grid_width=4, grid_height=4, magnitude=8)

p.sample(80)
# Out:
# Initialised with 95 image(s) found.
# Output directory set to C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/arnold_schwarzenegger\output.
# Executing Pipeline:   0%|          | 0/80 [00:00<?, ? Samples/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\Augmentor\Pipeline.py in _execute(self, augmentor_image, save_to_disk, multi_threaded)
#     250
# --> 251                         images[i].save(os.path.join(augmentor_image.output_directory, save_name))
#     252
#
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2349             else:
# -> 2350                 fp = builtins.open(filename, "w+b")
#    2351
#
# ...

# %%
p = Augmentor.Pipeline("C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/ben_afflek")
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.zoom(probability=0.5, min_factor=1.1, max_factor=1.5)
p.flip_top_bottom(probability=0.5)
p.random_distortion(probability=1, grid_width=4, grid_height=4, magnitude=8)

p.sample(80)
# Out:
# Initialised with 78 image(s) found.
# Output directory set to C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/ben_afflek\output.
# Executing Pipeline:   0%|          | 0/80 [00:00<?, ? Samples/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\Augmentor\Pipeline.py in _execute(self, augmentor_image, save_to_disk, multi_threaded)
#     250
# --> 251                         images[i].save(os.path.join(augmentor_image.output_directory, save_name))
#     252
#
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2349             else:
# -> 2350                 fp = builtins.open(filename, "w+b")
#    2351
#
# ...

# %%
p = Augmentor.Pipeline("C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/dwayne_johnson")
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.zoom(probability=0.5, min_factor=1.1, max_factor=1.5)
p.flip_top_bottom(probability=0.5)
p.random_distortion(probability=1, grid_width=4, grid_height=4, magnitude=8)

p.sample(80)
# Out:
# Initialised with 95 image(s) found.
# Output directory set to C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/dwayne_johnson\output.
# Executing Pipeline:   0%|          | 0/80 [00:00<?, ? Samples/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\Augmentor\Pipeline.py in _execute(self, augmentor_image, save_to_disk, multi_threaded)
#     250
# --> 251                         images[i].save(os.path.join(augmentor_image.output_directory, save_name))
#     252
#
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2349             else:
# -> 2350                 fp = builtins.open(filename, "w+b")
#    2351
#
# ...

# %%
p = Augmentor.Pipeline("C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/elton_john")
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.zoom(probability=0.5, min_factor=1.1, max_factor=1.5)
p.flip_top_bottom(probability=0.5)
p.random_distortion(probability=1, grid_width=4, grid_height=4, magnitude=8)

p.sample(80)
# Out:
# Initialised with 80 image(s) found.
# Output directory set to C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/elton_john\output.
# Executing Pipeline:   0%|          | 0/80 [00:00<?, ? Samples/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\Augmentor\Pipeline.py in _execute(self, augmentor_image, save_to_disk, multi_threaded)
#     250
# --> 251                         images[i].save(os.path.join(augmentor_image.output_directory, save_name))
#     252
#
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2349             else:
# -> 2350                 fp = builtins.open(filename, "w+b")
#    2351
#
# ...

# %%
p = Augmentor.Pipeline("C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/jerry_seinfeld")
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.zoom(probability=0.5, min_factor=1.1, max_factor=1.5)
p.flip_top_bottom(probability=0.5)
p.random_distortion(probability=1, grid_width=4, grid_height=4, magnitude=8)

p.sample(80)
# Out:
# Initialised with 101 image(s) found.
# Output directory set to C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/jerry_seinfeld\output.
# Processing <PIL.Image.Image image mode=RGB size=214x317 at 0x1AF81001940>:   1%|▏         | 1/80 [00:00<00:18,  4.33 Samples/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\Augmentor\Pipeline.py in _execute(self, augmentor_image, save_to_disk, multi_threaded)
#     250
# --> 251                         images[i].save(os.path.join(augmentor_image.output_directory, save_name))
#     252
#
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2349             else:
# -> 2350                 fp = builtins.open(filename, "w+b")
#    2351
#
# ...

# %%
p = Augmentor.Pipeline("C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/kate_beckinsale")
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.zoom(probability=0.5, min_factor=1.1, max_factor=1.5)
p.flip_top_bottom(probability=0.5)
p.random_distortion(probability=1, grid_width=4, grid_height=4, magnitude=8)

p.sample(80)
# Out:
# Initialised with 91 image(s) found.
# Output directory set to C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/kate_beckinsale\output.
# Executing Pipeline:   0%|          | 0/80 [00:00<?, ? Samples/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\Augmentor\Pipeline.py in _execute(self, augmentor_image, save_to_disk, multi_threaded)
#     250
# --> 251                         images[i].save(os.path.join(augmentor_image.output_directory, save_name))
#     252
#
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2349             else:
# -> 2350                 fp = builtins.open(filename, "w+b")
#    2351
#
# ...

# %%
p = Augmentor.Pipeline("C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/keanu_reeves")
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.zoom(probability=0.5, min_factor=1.1, max_factor=1.5)
p.flip_top_bottom(probability=0.5)
p.random_distortion(probability=1, grid_width=4, grid_height=4, magnitude=8)

p.sample(80)
# Out:
# Initialised with 80 image(s) found.
# Output directory set to C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/keanu_reeves\output.
# Executing Pipeline:   0%|          | 0/80 [00:00<?, ? Samples/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\Augmentor\Pipeline.py in _execute(self, augmentor_image, save_to_disk, multi_threaded)
#     250
# --> 251                         images[i].save(os.path.join(augmentor_image.output_directory, save_name))
#     252
#
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2349             else:
# -> 2350                 fp = builtins.open(filename, "w+b")
#    2351
#
# ...

# %%
p = Augmentor.Pipeline("C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/lauren_cohan")
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.zoom(probability=0.5, min_factor=1.1, max_factor=1.5)
p.flip_top_bottom(probability=0.5)
p.random_distortion(probability=1, grid_width=4, grid_height=4, magnitude=8)

p.sample(80)
# Out:
# Initialised with 90 image(s) found.
# Output directory set to C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/lauren_cohan\output.
# Executing Pipeline:   0%|          | 0/80 [00:00<?, ? Samples/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\Augmentor\Pipeline.py in _execute(self, augmentor_image, save_to_disk, multi_threaded)
#     250
# --> 251                         images[i].save(os.path.join(augmentor_image.output_directory, save_name))
#     252
#
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2349             else:
# -> 2350                 fp = builtins.open(filename, "w+b")
#    2351
#
# ...

# %%
p = Augmentor.Pipeline("C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/madonna")
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.zoom(probability=0.5, min_factor=1.1, max_factor=1.5)
p.flip_top_bottom(probability=0.5)
p.random_distortion(probability=1, grid_width=4, grid_height=4, magnitude=8)

p.sample(80)
# Out:
# Initialised with 68 image(s) found.
# Output directory set to C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/madonna\output.
# Processing <PIL.Image.Image image mode=RGB size=200x200 at 0x1AF80CB23C8>:   4%|▍         | 3/80 [00:00<00:08,  8.88 Samples/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\Augmentor\Pipeline.py in _execute(self, augmentor_image, save_to_disk, multi_threaded)
#     250
# --> 251                         images[i].save(os.path.join(augmentor_image.output_directory, save_name))
#     252
#
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2349             else:
# -> 2350                 fp = builtins.open(filename, "w+b")
#    2351
#
# ...

# %%
p = Augmentor.Pipeline("C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/mindy_kaling")
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.zoom(probability=0.5, min_factor=1.1, max_factor=1.5)
p.flip_top_bottom(probability=0.5)
p.random_distortion(probability=1, grid_width=4, grid_height=4, magnitude=8)

p.sample(80)
# Out:
# Initialised with 92 image(s) found.
# Output directory set to C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/mindy_kaling\output.
# Executing Pipeline:   0%|          | 0/80 [00:00<?, ? Samples/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\Augmentor\Pipeline.py in _execute(self, augmentor_image, save_to_disk, multi_threaded)
#     250
# --> 251                         images[i].save(os.path.join(augmentor_image.output_directory, save_name))
#     252
#
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2349             else:
# -> 2350                 fp = builtins.open(filename, "w+b")
#    2351
#
# ...

# %%
p = Augmentor.Pipeline("C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/simon_pegg")
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.zoom(probability=0.5, min_factor=1.1, max_factor=1.5)
p.flip_top_bottom(probability=0.5)
p.random_distortion(probability=1, grid_width=4, grid_height=4, magnitude=8)

p.sample(80)
# Out:
# Initialised with 94 image(s) found.
# Output directory set to C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/simon_pegg\output.
# Executing Pipeline:   0%|          | 0/80 [00:00<?, ? Samples/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\Augmentor\Pipeline.py in _execute(self, augmentor_image, save_to_disk, multi_threaded)
#     250
# --> 251                         images[i].save(os.path.join(augmentor_image.output_directory, save_name))
#     252
#
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2349             else:
# -> 2350                 fp = builtins.open(filename, "w+b")
#    2351
#
# ...

# %%
p = Augmentor.Pipeline("C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/sofia_vergara")
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.zoom(probability=0.5, min_factor=1.1, max_factor=1.5)
p.flip_top_bottom(probability=0.5)
p.random_distortion(probability=1, grid_width=4, grid_height=4, magnitude=8)

p.sample(80)
# Out:
# Initialised with 80 image(s) found.
# Output directory set to C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/sofia_vergara\output.
# Executing Pipeline:   0%|          | 0/80 [00:00<?, ? Samples/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\Augmentor\Pipeline.py in _execute(self, augmentor_image, save_to_disk, multi_threaded)
#     250
# --> 251                         images[i].save(os.path.join(augmentor_image.output_directory, save_name))
#     252
#
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2349             else:
# -> 2350                 fp = builtins.open(filename, "w+b")
#    2351
#
# ...

# %%
p = Augmentor.Pipeline("C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/will_smith")
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.zoom(probability=0.5, min_factor=1.1, max_factor=1.5)
p.flip_top_bottom(probability=0.5)
p.random_distortion(probability=1, grid_width=4, grid_height=4, magnitude=8)
# p.random_erasing(0.1,(10,10))

p.sample(80)
# Out:
# Initialised with 96 image(s) found.
# Output directory set to C:/Users/shadi/Desktop/term 7/hoosh/input/14-celebrity-faces-dataset/data/train/will_smith\output.
# Processing <PIL.Image.Image image mode=RGB size=538x599 at 0x1AFEE9E5668>:   5%|▌         | 4/80 [00:00<00:15,  4.98 Samples/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\Augmentor\Pipeline.py in _execute(self, augmentor_image, save_to_disk, multi_threaded)
#     250
# --> 251                         images[i].save(os.path.join(augmentor_image.output_directory, save_name))
#     252
#
# c:\Users\shadi\AppData\Local\Programs\Python\Python37\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2349             else:
# -> 2350                 fp = builtins.open(filename, "w+b")
#    2351
#
# ...
